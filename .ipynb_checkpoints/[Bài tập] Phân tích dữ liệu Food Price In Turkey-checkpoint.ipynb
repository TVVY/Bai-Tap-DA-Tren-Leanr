# %%
import pandas as pd
data = pd.read_csv('C:/Users/Pyter/DA/BaiTap/FoodPrice_in_Turkey.csv', encoding= 'UTF-8')
data.head(66)
# Out:
#                Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0   National Average         52  Rice - Retail     5     KG      5  2013
# 1   National Average         52  Rice - Retail     5     KG      6  2013
# 2   National Average         52  Rice - Retail     5     KG     11  2013
# 3   National Average         52  Rice - Retail     5     KG     12  2013
# 4   National Average         52  Rice - Retail     5     KG      1  2014
# ..               ...        ...            ...   ...    ...    ...   ...
# 61  National Average         52  Rice - Retail     5     KG      8  2019
# 62  National Average         52  Rice - Retail     5     KG      9  2019
# 63  National Average         52  Rice - Retail     5     KG     10  2019
# 64  National Average         52  Rice - Retail     5     KG     11  2019
# 65  National Average         52  Rice - Retail     5     KG     12  2019
#
#      Price
# 0   4.4920
# 1   4.5786
# 2   4.7865
# 3   5.1337
# 4   5.5099
# ..     ...
# ...

# %%
print('Số dòng là:', data.shape[0], ', Số cột là:', data.shape[1])
# Out:
# Số dòng là: 7381 , Số cột là: 8

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
data.groupby(['ProductName'])['Price'].mean().sort_values(ascending=True)
# Out:
# ProductName
# Eggs - Retail                                               0.505925
# Electricity - Retail                                        0.513580
# Cabbage - Retail                                            1.723395
# Salt - Retail                                               2.048213
# Onions - Retail                                             2.141539
# Cucumbers (greenhouse) - Retail                             2.206807
# Potatoes - Retail                                           2.297231
# Apples (red) - Retail                                       2.392193
# Bread (pita) - Retail                                       2.404545
# Transport (public) - Retail                                 2.468031
# Peas (green, dry) - Retail                                  2.900029
# Oranges - Retail                                            3.124280
# Spinach - Retail                                            3.240587
# ...
