# %%
import pandas as pd
import numpy as np

data = pd.read_csv('C:/Users/Pyter/DA/BaiTap/house_price_Dống-Da_Hà-Nội_subdata.csv',header=0)
data
# Out:
#       area    price  postDate land_certificate house_direction  \
# 0     50.0  14700.0     44197            So do             NaN
# 1     57.0   4200.0     44265            So do             Nam
# 2     62.0  11000.0     44268            So do             NaN
# 3     26.0   2900.0     44292            So do             NaN
# 4     40.0   3950.0     44292            So do             NaN
# ..     ...      ...       ...              ...             ...
# 666  168.0  23500.0     44325              NaN             NaN
# 667   65.0  17500.0     44325            So do             NaN
# 668   60.0  17500.0     44197              NaN             NaN
# 669   45.0  24800.0     44197              NaN             NaN
# 670  107.0  45000.0     44325            So do             NaN
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0                 NaN     4.0      6.0    6.0  21.015698  105.824583
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   area               665 non-null    float64
#  1   price              617 non-null    float64
#  2   postDate           671 non-null    int64
#  3   land_certificate   369 non-null    object
#  4   house_direction    42 non-null     object
#  5   balcony_direction  24 non-null     object
#  6   toilet             240 non-null    float64
#  7   bedroom            320 non-null    float64
#  8   floor              366 non-null    float64
#  9   lat                671 non-null    float64
#  10  long               671 non-null    float64
#  11  property_type      671 non-null    object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 63.0+ KB

# %%
data.describe()
# Out:
#                area         price      postDate      toilet    bedroom  \
# count    665.000000  6.170000e+02    671.000000  240.000000  320.00000
# mean     103.763534  2.892758e+04  44259.903130    3.645833    4.31875
# std      471.861867  1.464474e+05     58.280392    2.349126    2.58976
# min        0.000000  4.500000e+00  44197.000000    1.000000    1.00000
# 25%       39.000000  3.950000e+03  44197.000000    2.000000    3.00000
# 50%       55.000000  8.900000e+03  44292.000000    4.000000    4.00000
# 75%       80.000000  2.150000e+04  44312.000000    4.250000    6.00000
# max    11000.000000  3.300000e+06  44325.000000   16.000000   22.00000
#
#             floor         lat        long
# count  366.000000  671.000000  671.000000
# mean     4.762295   21.015733  105.825550
# std      1.676853    0.006517    0.009011
# min      1.000000   20.998499  105.795544
# 25%      4.000000   21.011094  105.822605
# 50%      5.000000   21.018072  105.828985
# ...

# %%
# Phát hiện các dòng, cột chứa dữ liệu khuyết thiếu
for index, column in enumerate(data.columns):
    temp = data.loc[:,column].isna()
    if temp.sum() > 0:
        print('cột ' , data.columns[index], ' chứa ' , temp.sum() , ' giá trị KT')
print('Tổng số lượng dòng có chứa giá trị khuyết thiếu là: ', data.shape[0] - data.dropna().shape[0])
# Out:
# cột  area  chứa  6  giá trị KT
# cột  price  chứa  54  giá trị KT
# cột  land_certificate  chứa  302  giá trị KT
# cột  house_direction  chứa  629  giá trị KT
# cột  balcony_direction  chứa  647  giá trị KT
# cột  toilet  chứa  431  giá trị KT
# cột  bedroom  chứa  351  giá trị KT
# cột  floor  chứa  305  giá trị KT
# Tổng số lượng dòng có chứa giá trị khuyết thiếu là:  657

# %%
# Xóa bỏ hết tất cả những dòng dữ liệu không có thông tin về giá
data.dropna(subset=['price'], inplace=True)

# %%
# Thực hiện xử lý giá trị khuyết thiếu: Thay thế giá trị khuyết thiếu của land_certificate bằng =”không có thông tin”,
# house_direction, balcony_direction, toilet, bedroom, Floor  bằng giá trị có tần số xuất hiện lớn nhất của các thuộc tính đó
values = {'land_certificate':'không có thông tin'}
data.fillna(value=values, inplace=True)

# %%
values = {'house_direction':data.loc[:,'house_direction'].mode()[0],
         'balcony_direction':data.loc[:,'balcony_direction'].mode()[0],
         'toilet':data.loc[:,'toilet'].mode()[0],
         'bedroom':data.loc[:,'bedroom'].mode()[0],
         'floor':data.loc[:,'floor'].mode()[0]}
data.fillna(value=values, inplace=True)
data
# Out:
#       area    price  postDate    land_certificate house_direction  \
# 0     50.0  14700.0     44197               So do        dong-Nam
# 1     57.0   4200.0     44265               So do             Nam
# 2     62.0  11000.0     44268               So do        dong-Nam
# 3     26.0   2900.0     44292               So do        dong-Nam
# 4     40.0   3950.0     44292               So do        dong-Nam
# ..     ...      ...       ...                 ...             ...
# 666  168.0  23500.0     44325  không có thông tin        dong-Nam
# 667   65.0  17500.0     44325               So do        dong-Nam
# 668   60.0  17500.0     44197  không có thông tin        dong-Nam
# 669   45.0  24800.0     44197  không có thông tin        dong-Nam
# 670  107.0  45000.0     44325               So do        dong-Nam
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0            dong-Nam     4.0      6.0    6.0  21.015698  105.824583
# ...

# %%
# Lọc thông tin những bất động sản ở trong ngõ thành bộ dữ liệu nhà ngõ
nhango = data[(data.loc[:,'property_type']=='trong ngo')]

# %%
# Tính toán giá/m2  ( đơn vị triệu/m2) với loại hình nhà ngõ
nhango.loc[:,'giá (triệu/m2)'] = nhango.loc[:,'price'] / nhango.loc[:,'area']
nhango.dropna(subset = ['giá (triệu/m2)'], inplace = True)
# Out:
# C:\Users\Pyter\AppData\Local\Temp\ipykernel_14568\291107322.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nhango.loc[:,'giá (triệu/m2)'] = nhango.loc[:,'price'] / nhango.loc[:,'area']
# C:\Users\Pyter\AppData\Local\Temp\ipykernel_14568\291107322.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nhango.dropna(subset = ['giá (triệu/m2)'], inplace = True)

# %%
nhango
# Out:
#      area    price  postDate    land_certificate house_direction  \
# 0    50.0  14700.0     44197               So do        dong-Nam
# 1    57.0   4200.0     44265               So do             Nam
# 2    62.0  11000.0     44268               So do        dong-Nam
# 3    26.0   2900.0     44292               So do        dong-Nam
# 4    40.0   3950.0     44292               So do        dong-Nam
# ..    ...      ...       ...                 ...             ...
# 444  90.0  32000.0     44325  không có thông tin        dong-Bac
# 445  58.0  15800.0     44325               So do        dong-Nam
# 446  96.0  10200.0     44325               So do        dong-Nam
# 447  38.0   3900.0     44325               So do        dong-Nam
# 448  25.0   2850.0     44325  không có thông tin        dong-Nam
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0            dong-Nam     4.0      6.0    6.0  21.015698  105.824583
# ...

# %%
# Phát hiện giá trị ngoại lai của các thuộc tính: diện tích, giá/m2 bằng phương pháp IQR
# Thực hiện loại bỏ các dòng dữ liệu ngoại lai
a = nhango.loc[:,['area','giá (triệu/m2)']]
Q1 = a.quantile(0.25)
Q3 = a.quantile(0.75)
IQR = Q3 - Q1
b = nhango[~((a < (Q1 - 1.5 * IQR)) | (a > (Q3 + 1.5 * IQR))).any(axis=1)]
print(f'Số giá trị ngoại lai bị bỏ đi là {nhango.shape[0]-b.shape[0]}')
# Out:
# Số giá trị ngoại lai bị bỏ đi là 53

# %%
b
# Out:
#      area    price  postDate    land_certificate house_direction  \
# 0    50.0  14700.0     44197               So do        dong-Nam
# 1    57.0   4200.0     44265               So do             Nam
# 2    62.0  11000.0     44268               So do        dong-Nam
# 3    26.0   2900.0     44292               So do        dong-Nam
# 4    40.0   3950.0     44292               So do        dong-Nam
# ..    ...      ...       ...                 ...             ...
# 443  25.0   2850.0     44325  không có thông tin        dong-Nam
# 445  58.0  15800.0     44325               So do        dong-Nam
# 446  96.0  10200.0     44325               So do        dong-Nam
# 447  38.0   3900.0     44325               So do        dong-Nam
# 448  25.0   2850.0     44325  không có thông tin        dong-Nam
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0            dong-Nam     4.0      6.0    6.0  21.015698  105.824583
# ...

# %%
# nhango['giá (triệu/m2)'] = nhango['giá (triệu/m2)'].astype('float')

# %%
nhango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406 entries, 0 to 448
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   area               406 non-null    float64
#  1   price              406 non-null    float64
#  2   postDate           406 non-null    int64
#  3   land_certificate   406 non-null    object
#  4   house_direction    406 non-null    object
#  5   balcony_direction  406 non-null    object
#  6   toilet             406 non-null    float64
#  7   bedroom            406 non-null    float64
#  8   floor              406 non-null    float64
#  9   lat                406 non-null    float64
#  10  long               406 non-null    float64
#  11  property_type      406 non-null    object
#  12  giá (triệu/m2)     406 non-null    float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 44.4+ KB

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
ss = StandardScaler()
mm = MinMaxScaler()
rs = RobustScaler()

sss = ss.fit_transform(pd.DataFrame(nhango.loc[:,['area','giá (triệu/m2)']]))
# mms = mm.fit_transform(pd.DataFrame(nhango['giá (triệu/m2)']))
# rbs = rs.fit_transform(pd.DataFrame(nhango['giá (triệu/m2)']))

# col_names = list(pd.DataFrame(nhango['giá (triệu/m2)']).columns)
# sss = pd.DataFrame(sss, columns=col_names)

# col_names1 = list(pd.DataFrame(nhango['giá (triệu/m2)']).columns)
# mms = pd.DataFrame(mms, columns=col_names1)

# col_names2 = list(pd.DataFrame(nhango['giá (triệu/m2)']).columns)
# rbs = pd.DataFrame(rbs, columns=col_names2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 6>()
#       3 mm = MinMaxScaler()
#       4 rs = RobustScaler()
# ----> 6 sss = ss.fit_transform(pd.DataFrame(nhango.loc[:,['area','giá (triệu/m2)']]))
#
# File D:\ana\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# ...

# %%
import seaborn as sns

sns.kdeplot(data=nhango['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data=sss)
# Out:
# <AxesSubplot:ylabel='Density'>
