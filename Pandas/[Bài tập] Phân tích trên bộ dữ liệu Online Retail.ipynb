# %%
import pandas as pd
data = pd.read_csv('C:/Users/Pyter/DA/BaiTap/OnlineRetail.csv',header=0 , encoding = "ISO-8859-1")
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
print('Số dòng là:', data.shape[0], ', Số cột là:', data.shape[1])
data.dtypes
# Out:
# Số dòng là: 541909 , Số cột là: 8
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
data1 = data.loc[:,['Description','Quantity']]
data1.to_csv('OnlineRetail.csv')
data1
# Out:
#                                 Description  Quantity
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6
# 1                       WHITE METAL LANTERN         6
# 2            CREAM CUPID HEARTS COAT HANGER         8
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4            RED WOOLLY HOTTIE WHITE HEART.         6
# ...                                     ...       ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12
# 541905         CHILDREN'S APRON DOLLY GIRL          6
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908        BAKING SET 9 PIECE RETROSPOT          3
#
# [541909 rows x 2 columns]

# %%
data2 = data.iloc[0:1001]
data2.to_excel('OnlineRetail.xlsx')
data2
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 996     536520     22100             SKULLS SQUARE TISSUE BOX         1
# 997     536520     22096      PINK PAISLEY SQUARE TISSUE BOX          1
# 998     536520     22583         PACK OF 6 HANDBAG GIFT BOXES         1
# 999     536520     21358           TOAST ITS - HAPPY BIRTHDAY         2
# 1000    536520     21123  SET/10 IVORY POLKADOT PARTY CANDLES         1
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data3 = data[data.Quantity == 10]
data3.to_hdf('OnlineRetail.h5','table')
data3
# Out:
# C:\Users\Pyter\AppData\Local\Temp\ipykernel_5104\3889295940.py:2: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['InvoiceNo', 'StockCode', 'Description', 'InvoiceDate', 'Country'], dtype='object')]
#
#   data3.to_hdf('OnlineRetail.h5','table')
#        InvoiceNo StockCode                      Description  Quantity  \
# 86        536378     22386          JUMBO BAG PINK POLKADOT        10
# 87        536378    85099C   JUMBO  BAG BAROQUE BLACK WHITE        10
# 88        536378     21033  JUMBO BAG CHARLIE AND LOLA TOYS        10
# 89        536378     20723         STRAWBERRY CHARLOTTE BAG        10
# 93        536378     20725          LUNCH BAG RED RETROSPOT        10
# ...          ...       ...                              ...       ...
# 541810    581579     20713                   JUMBO BAG OWLS        10
# ...

# %%
#cách 1
data4 = data.iloc[1000:2001,3:6]
data4.to_json('OnlineRetail.json',orient='columns')
data4
# Out:
#       Quantity      InvoiceDate  UnitPrice
# 1000         1  12/1/2010 12:43       1.25
# 1001         1  12/1/2010 12:43       1.25
# 1002         1  12/1/2010 12:43       1.25
# 1003         1  12/1/2010 12:43       1.25
# 1004        12  12/1/2010 12:43       0.29
# ...        ...              ...        ...
# 1996         1  12/1/2010 14:34       2.95
# 1997         3  12/1/2010 14:34       1.65
# 1998         1  12/1/2010 14:34       4.95
# 1999         1  12/1/2010 14:34       2.95
# 2000         2  12/1/2010 14:34       1.25
#
# [1001 rows x 3 columns]

# %%
#cách 2
data5 = data.loc[1000:2000,['Quantity', 'InvoiceDate', 'UnitPrice']]
data5.to_json('OnlineRetail.json1')
data5
# Out:
#       Quantity      InvoiceDate  UnitPrice
# 1000         1  12/1/2010 12:43       1.25
# 1001         1  12/1/2010 12:43       1.25
# 1002         1  12/1/2010 12:43       1.25
# 1003         1  12/1/2010 12:43       1.25
# 1004        12  12/1/2010 12:43       0.29
# ...        ...              ...        ...
# 1996         1  12/1/2010 14:34       2.95
# 1997         3  12/1/2010 14:34       1.65
# 1998         1  12/1/2010 14:34       4.95
# 1999         1  12/1/2010 14:34       2.95
# 2000         2  12/1/2010 14:34       1.25
#
# [1001 rows x 3 columns]

# %%
data6 = data[data.InvoiceNo == '536365']
data6.to_html('OnlineRetail.html')
data6
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# ...
